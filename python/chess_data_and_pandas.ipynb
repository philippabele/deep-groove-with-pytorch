# %% [markdown]
# # Playing with data
#
# ## Load Data from CSV

# %%
import pandas as pd

df = pd.read_csv("data/top_women_chess_players_aug_2020.csv")
df
# Out:
#       Fide id                     Name Federation Gender  Year_of_birth Title  \
# 0      700070            Polgar, Judit        HUN      F         1976.0    GM
# 1     8602980               Hou, Yifan        CHN      F         1994.0    GM
# 2     5008123            Koneru, Humpy        IND      F         1987.0    GM
# 3     4147103  Goryachkina, Aleksandra        RUS      F         1998.0    GM
# 4      700088            Polgar, Susan        HUN      F         1969.0    GM
# ...       ...                      ...        ...    ...            ...   ...
# 8548  3302288        Reinkens, Natalia        BOL      F            NaN   NaN
# 8549   343960        Saffova, Michaela        CZE      F         1994.0   NaN
# 8550  5038294         Shetye, Siddhali        IND      F         1992.0   NaN
# 8551  2072491            Trakru, Priya        USA      F         2001.0   WFM
# 8552  4666399      Vorpahl, Sina Fleur        GER      F         1982.0   NaN
#
# ...

# %% [markdown]
# ## Displaying Data
#
# show the first 2 and the last 2 rows of the dataset

# %%
df.head(2)
# Out:
#    Fide id           Name Federation Gender  Year_of_birth Title  \
# 0   700070  Polgar, Judit        HUN      F         1976.0    GM
# 1  8602980     Hou, Yifan        CHN      F         1994.0    GM
#
#    Standard_Rating  Rapid_rating  Blitz_rating Inactive_flag
# 0             2675        2646.0        2736.0            wi
# 1             2658        2621.0        2601.0           NaN

# %%
df.tail(2)
# Out:
#       Fide id                 Name Federation Gender  Year_of_birth Title  \
# 8551  2072491        Trakru, Priya        USA      F         2001.0   WFM
# 8552  4666399  Vorpahl, Sina Fleur        GER      F         1982.0   NaN
#
#       Standard_Rating  Rapid_rating  Blitz_rating Inactive_flag
# 8551             1801           NaN           NaN            wi
# 8552             1801           NaN           NaN            wi

# %% [markdown]
# read each column

# %%
df[['Name', 'Federation']]
# Out:
#                          Name Federation
# 0               Polgar, Judit        HUN
# 1                  Hou, Yifan        CHN
# 2               Koneru, Humpy        IND
# 3     Goryachkina, Aleksandra        RUS
# 4               Polgar, Susan        HUN
# ...                       ...        ...
# 8548        Reinkens, Natalia        BOL
# 8549        Saffova, Michaela        CZE
# 8550         Shetye, Siddhali        IND
# 8551            Trakru, Priya        USA
# 8552      Vorpahl, Sina Fleur        GER
#
# [8553 rows x 2 columns]

# %% [markdown]
# row 0 to 2

# %%
df.iloc[0:2]
# Out:
#    Fide id           Name Federation Gender  Year_of_birth Title  \
# 0   700070  Polgar, Judit        HUN      F         1976.0    GM
# 1  8602980     Hou, Yifan        CHN      F         1994.0    GM
#
#    Standard_Rating  Rapid_rating  Blitz_rating Inactive_flag
# 0             2675        2646.0        2736.0            wi
# 1             2658        2621.0        2601.0           NaN

# %% [markdown]
# show cell 5 of row 0

# %%
df.iloc[0,5]
# Out:
# 'GM'

# %% [markdown]
# ## Work with Data

# %% [markdown]
# get overall information of the Dataframe

# %%
df.describe()
# Out:
#             Fide id  Year_of_birth  Standard_Rating  Rapid_rating  \
# count  8.553000e+03    8261.000000      8553.000000   3608.000000
# mean   8.829011e+06    1985.291732      2005.102303   1931.680155
# std    9.226777e+06      14.055386       137.146646    191.449272
# min    1.001450e+05    1920.000000      1801.000000   1224.000000
# 25%    2.119447e+06    1978.000000      1891.000000   1811.000000
# 50%    4.500539e+06    1988.000000      1998.000000   1921.000000
# 75%    1.360553e+07    1995.000000      2090.000000   2051.000000
# max    7.360114e+07    2010.000000      2675.000000   2646.000000
#
#        Blitz_rating
# count   3472.000000
# mean    1925.155242
# std      188.556849
# min     1159.000000
# 25%     1805.000000
# 50%     1919.000000
# 75%     2044.000000
# max     2736.000000

# %% [markdown]
# get all Players, which blitz rating is more then 100 MMR greater than their standard rating

# %%
df.loc[df['Standard_Rating'] < (df['Blitz_rating']-100)]
# Out:
#        Fide id                     Name Federation Gender  Year_of_birth  \
# 605    4200446      Botsari, Anna-Maria        GRE      F         1972.0
# 645   24605611            Fuchs, Judith        GER      F         1990.0
# 651    3504794  Linares Napoles, Oleiny        CUB      F         1983.0
# 798   12401455         Hoang, Thi Nhu Y        VIE      F         1993.0
# 1001    601632       Haussernot, Cecile        FRA      F         1998.0
# ...        ...                      ...        ...    ...            ...
# 8248   1104551         Leszner, Liliana        POL      F         1965.0
# 8253  10201220           Sultana, Zakia        BAN      F         1967.0
# 8475  14142040        Irgasheva, Zorina        UKR      F         1995.0
# 8507  30937000              Chen, Minda        USA      F         2004.0
# 8511    601926          Dubois, Martine        MNC      F         1959.0
#
#      Title  Standard_Rating  Rapid_rating  Blitz_rating Inactive_flag
# ...

# %% [markdown]
# All Players from Germany that are younger than or got 18 in 2022

# %%
df.loc[(df['Federation'] == 'GER') & (df['Year_of_birth']+18 > 2022)]
# Out:
#        Fide id                 Name Federation Gender  Year_of_birth Title  \
# 1937  12962554  Ziegenfuss, Antonia        GER      F         2005.0   WFM
# 4718  12983292     Bashylina, Luisa        GER      F         2006.0   WCM
# 5956  12993743       Dietz, Kristin        GER      F         2005.0   NaN
# 6087  16236947   Wagner, Margarethe        GER      F         2006.0   NaN
# 6100  12995444        Reuter, Elisa        GER      F         2005.0   WCM
# 6672  12993859    Butenandt, Svenja        GER      F         2006.0   NaN
# 6847  16217136      Zhou, Lepu Coco        GER      F         2007.0   NaN
# 7353  16211138       Peglau, Mirjam        GER      F         2005.0   NaN
# 7757  16244729      Heutling, Elina        GER      F         2005.0   NaN
# 8312  12989746      Liu, Sijia Anna        GER      F         2005.0   NaN
# 8378  16236890        Doll, Rebecca        GER      F         2005.0   NaN
#
#       Standard_Rating  Rapid_rating  Blitz_rating Inactive_flag
# ...

# %% [markdown]
# Showing the best Anna

# %%
df.loc[(df['Name'].str.contains('Anna'))].max()
# Out:
# C:\Users\rkurs\AppData\Local\Temp\ipykernel_15148\425682452.py:1: FutureWarning: The default value of numeric_only in DataFrame.max is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.loc[(df['Name'].str.contains('Anna'))].max()
# Fide id                 54180058
# Name               Zozulia, Anna
# Federation                   USA
# Gender                         F
# Year_of_birth             2009.0
# Standard_Rating             2535
# Rapid_rating              2533.0
# Blitz_rating              2505.0
# dtype: object

# %% [markdown]
# Sorting the dataframe acording to the standard rating.

# %%
df.sort_values(['Standard_Rating', 'Rapid_rating', 'Blitz_rating'], ascending=False)
# Out:
#        Fide id                     Name Federation Gender  Year_of_birth  \
# 0       700070            Polgar, Judit        HUN      F         1976.0
# 1      8602980               Hou, Yifan        CHN      F         1994.0
# 2      5008123            Koneru, Humpy        IND      F         1987.0
# 3      4147103  Goryachkina, Aleksandra        RUS      F         1998.0
# 4       700088            Polgar, Susan        HUN      F         1969.0
# ...        ...                      ...        ...    ...            ...
# 8545   3604390     Morales Checa, Karla        ECU      F            NaN
# 8547  24643440         Neubacher, Doris        GER      F         1968.0
# 8548   3302288        Reinkens, Natalia        BOL      F            NaN
# 8551   2072491            Trakru, Priya        USA      F         2001.0
# 8552   4666399      Vorpahl, Sina Fleur        GER      F         1982.0
#
#      Title  Standard_Rating  Rapid_rating  Blitz_rating Inactive_flag
# ...
