# %% [markdown]
# # PyTopch
#
# ## OPTIMIZING MODEL PARAMETERS
#
# iteration = epoch
#
# ### Prerequisite Code

# %%
import torch
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor

training_data = datasets.FashionMNIST(
    root="data",
    train=True,
    download=True,
    transform=ToTensor()
)

test_data = datasets.FashionMNIST(
    root="data",
    train=False,
    download=True,
    transform=ToTensor()
)

count = 0
for i, (data, labels) in enumerate(test_data):
    if i >= count: break
    print(data, labels)

# %%
training_data
# Out:
# Dataset FashionMNIST
#     Number of datapoints: 60000
#     Root location: data
#     Split: Train
#     StandardTransform
# Transform: ToTensor()

# %%
train_dataloader = DataLoader(training_data, batch_size=64)
train_dataloader

# %%
test_dataloader = DataLoader(test_data, batch_size=64)
test_dataloader

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(28*28, 512),
            nn.ReLU(),
            nn.Linear(512, 512),
            nn.ReLU(),
            nn.Linear(512, 10),
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

model = NeuralNetwork()

model
# Out:
# NeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=784, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=512, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=512, out_features=10, bias=True)
#   )
# )

# %%
learning_rate = 1e-3
batch_size = 64
epochs = 5

loss_fn = nn.CrossEntropyLoss()

optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

# %%
def train_loop(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    print(f"Dataloader {dataloader}")
    for batch, (X, y) in enumerate(dataloader):
        # Compute prediction and loss
        print(f"X: {X.dtype}")

        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if batch % 100 == 0:
            loss, current = loss.item(), batch * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")


def test_loop(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss, correct = 0, 0

    with torch.no_grad():
        for X, y in dataloader:
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()

    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

epochs = 10
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train_loop(train_dataloader, model, loss_fn, optimizer)
    test_loop(test_dataloader, model, loss_fn)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# X: torch.float32
# loss: 2.305336  [    0/60000]
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# loss: 2.296686  [ 6400/60000]
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# loss: 2.274026  [12800/60000]
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# loss: 2.261719  [19200/60000]
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# loss: 2.261907  [25600/60000]
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# loss: 2.214945  [32000/60000]
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# loss: 2.238882  [38400/60000]
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# loss: 2.194975  [44800/60000]
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# loss: 2.191954  [51200/60000]
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# loss: 2.162680  [57600/60000]
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# Test Error:
#  Accuracy: 31.9%, Avg loss: 2.157545
#
# Epoch 2
# -------------------------------
# X: torch.float32
# loss: 2.171966  [    0/60000]
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# loss: 2.165909  [ 6400/60000]
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# loss: 2.102999  [12800/60000]
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# loss: 2.111118  [19200/60000]
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# loss: 2.080395  [25600/60000]
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# loss: 2.007011  [32000/60000]
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# X: torch.float32
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 7
#       5 for t in range(epochs):
#       6     print(f"Epoch {t+1}\n-------------------------------")
# ----> 7     train_loop(train_dataloader, model, loss_fn, optimizer)
#       8     test_loop(test_dataloader, model, loss_fn)
#       9 print("Done!")
#
# Cell In[7], line 12, in train_loop(dataloader, model, loss_fn, optimizer)
#      10 # Backpropagation
#      11 optimizer.zero_grad()
# ---> 12 loss.backward()
#      13 optimizer.step()
#      15 if batch % 100 == 0:
#
# File c:\Users\kur\Documents\GitHub\dhbw-deep-groove-with-pytorch\deep_groove_project\venv\lib\site-packages\torch\_tensor.py:487, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     477 if has_torch_function_unary(self):
#     478     return handle_torch_function(
#     479         Tensor.backward,
#     480         (self,),
#    (...)
#     485         inputs=inputs,
#     486     )
# --> 487 torch.autograd.backward(
#     488     self, gradient, retain_graph, create_graph, inputs=inputs
#     489 )
#
# File c:\Users\kur\Documents\GitHub\dhbw-deep-groove-with-pytorch\deep_groove_project\venv\lib\site-packages\torch\autograd\__init__.py:197, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     192     retain_graph = create_graph
#     194 # The reason we repeat same the comment below is that
#     195 # some Python versions print out the first line of a multi-line function
#     196 # calls in the traceback and some print out the last line
# --> 197 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     198     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     199     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:
